# %% [markdown]
# # Facial Recognition via Deep Learning
#
# [Deep learning](https://en.wikipedia.org/wiki/Deep_learning) is a branch of machine learning that relies primarily on [neural networks](https://en.wikipedia.org/wiki/Neural_network). Neural networks are built with libraries such as [TensorFlow](https://www.tensorflow.org/) and [Keras](https://keras.io/). The latter is an open-source Python library that dramatically simplifies the building of neural networks. Under the hood, it uses TensorFlow and other frameworks to do the heavy lifting. With Keras, you can build sophisticated neural networks with just a few lines of code and train them to classify images, analyze text for sentiment, and perform other tasks at which deep learning excels.
#
# Let's use Keras to build a neural network that recognizes faces. You will train it with images from the famous [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset. Along the way, you will learn the basics of building, training, and evaluating neural networks.

# %% [markdown]
# ## Load the dataset
#
# The first step is to import facial images from the dataset. LFW contains more than 13,000 facial images collected from the Web. Of the more than 5,000 people represented in the dataset, 1,680 have two or more facial images, while only five have 100 or more. We'll set the minimum number of faces per person to 100, which means that five sets of faces corresponding to five famous people will be imported. Each facial image is labeled with the name of the person that the face belongs to.

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import fetch_lfw_people

faces = fetch_lfw_people(min_faces_per_person=100)
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)

print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1,140 facial images were loaded. Each image measures 47 x 62 pixels for a total of 2,914 pixels per image. That means we're working with a model with 2,914 feature columns. Use the following code to show the first 24 images in the dataset and the people to whom the faces belong.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# Check the balance in the dataset by generating a histogram showing how many facial images were imported for each person.

# %%
from collections import Counter
counts = Counter(faces.target)
names = {}

for key in counts.keys():
    names[faces.target_names[key]] = counts[key]

df = pd.DataFrame.from_dict(names, orient='index')
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The dataset is not very well balanced, and that's a concern because classification models are best trained with balanced datasets. Use the following code to build a dataset containing 100 images of each person.

# %%
mask = np.zeros(faces.target.shape, dtype=bool)

for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
    
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %% [markdown]
# The next step is to normalize pixel values by dividing them by 255, and to convert the target values (the 0-based indices identifying the person that belongs to a face) into categorical values by [one-hot-encoding](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f) them. After that, we'll split the data for training and testing. Rather than allow Keras to do the splitting, we'll use Scikit-learn so we can validate the network with data it hasn't seen before.

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

face_images = x_faces / 255
face_labels = to_categorical(y_faces)
                             
x_train, x_test, y_train, y_test = train_test_split(face_images, face_labels, train_size=0.8, stratify=face_labels, random_state=0)

# %% [markdown]
# ## Build and train a neural network
#
# Start by using Keras to build and train a neural network containing one hidden layer with 512 neurons. We'll use `categorical_crossentropy` as the loss function and a `softmax` output layer since this is a multiclass classification task. We will also use `adam` as the optimization algorithm. Rather than use a fixed learning rate, `adam` varies the learning rate as training proceeds so the network learns faster in the early stages of training and (hopefully) converges more accurately toward a solution in later stages.

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
 
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1492480
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now train the network and plot the training and validation accuracy.

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 10ms/step - loss: 3.6126 - accuracy: 0.1975 - val_loss: 2.0750 - val_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8230 - accuracy: 0.2600 - val_loss: 1.7472 - val_accuracy: 0.2400
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4410 - accuracy: 0.4200 - val_loss: 1.4305 - val_accuracy: 0.4500
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3532 - accuracy: 0.4575 - val_loss: 1.3240 - val_accuracy: 0.5200
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3111 - accuracy: 0.4750 - val_loss: 1.2558 - val_accuracy: 0.5900
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1904 - accuracy: 0.5575 - val_loss: 1.4967 - val_accuracy: 0.4300
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3274 - accuracy: 0.4550 - val_loss: 1.3335 - val_accuracy: 0.5700
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2586 - accuracy: 0.5725 - val_loss: 1.3068 - val_accuracy: 0.5100
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0124 - accuracy: 0.6525 - val_loss: 1.2544 - val_accuracy: 0.5000
# Epoch 10/100
# 20/20 [==============================] - 0s 3ms/step - loss: 1.0323 - accuracy: 0.6125 - val_loss: 1.1508 - val_accuracy: 0.4900
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9417 - accuracy: 0.6750 - val_loss: 1.1471 - val_accuracy: 0.5700
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8683 - accuracy: 0.7225 - val_loss: 1.0135 - val_accuracy: 0.6300
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7963 - accuracy: 0.7300 - val_loss: 1.0360 - val_accuracy: 0.6200
# Epoch 14/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7570 - accuracy: 0.7575 - val_loss: 1.1448 - val_accuracy: 0.6000
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7213 - accuracy: 0.7775 - val_loss: 1.0784 - val_accuracy: 0.5900
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6619 - accuracy: 0.7825 - val_loss: 0.9137 - val_accuracy: 0.7400
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6066 - accuracy: 0.8275 - val_loss: 0.9759 - val_accuracy: 0.6600
# Epoch 18/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6437 - accuracy: 0.7800 - val_loss: 1.0569 - val_accuracy: 0.5900
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6139 - accuracy: 0.8125 - val_loss: 0.8555 - val_accuracy: 0.7000
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5995 - accuracy: 0.7950 - val_loss: 0.8805 - val_accuracy: 0.6800
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5596 - accuracy: 0.8025 - val_loss: 0.9920 - val_accuracy: 0.6200
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5125 - accuracy: 0.8325 - val_loss: 0.8320 - val_accuracy: 0.7100
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5712 - accuracy: 0.8025 - val_loss: 0.9333 - val_accuracy: 0.6900
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.
100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9975 - val_loss: 0.7079 - val_accuracy: 0.8400
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0339 - accuracy: 1.0000 - val_loss: 0.6822 - val_accuracy: 0.8400
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 1.0000 - val_loss: 0.7554 - val_accuracy: 0.7900
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0441 - accuracy: 0.9950 - val_loss: 0.7491 - val_accuracy: 0.8200
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0376 - accuracy: 1.0000 - val_loss: 0.7099 - val_accuracy: 0.7900
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.8141 - val_accuracy: 0.8300
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0268 - accuracy: 1.0000 - val_loss: 0.7792 - val_accuracy: 0.7900
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0330 - accuracy: 1.0000 - val_loss: 0.7792 - val_accuracy: 0.8000
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0407 - accuracy: 0.9950 - val_loss: 0.8102 - val_accuracy: 0.8200
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.7574 - val_accuracy: 0.7800
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.7137 - val_accuracy: 0.8300
# Epoch 96/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 1.0000 - val_loss: 0.7168 - val_accuracy: 0.8300
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0305 - accuracy: 1.0000 - val_loss: 0.8134 - val_accuracy: 0.8400
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 1.0000 - val_loss: 0.7781 - val_accuracy: 0.8000
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 0.9975 - val_loss: 0.7595 - val_accuracy: 0.7900
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 1.0000 - val_loss: 0.7516 - val_accuracy: 0.8100
# []

# %% [markdown]
# Finally, use the test data to generate a confusion matrix to visualize how the network performs.

# %%
from sklearn.metrics import ConfusionMatrixDisplay as cmd

sns.reset_orig()
y_predicted = model.predict(x_test)
fig, ax = plt.subplots(figsize=(6, 6))
ax.grid(False)

cmd.from_predictions(y_test.argmax(axis=1), y_predicted.argmax(axis=1),
                     display_labels=faces.target_names, colorbar=False,
                     cmap='Blues', xticks_rotation='vertical', ax=ax)

# %% [markdown]
# How many times did the model correctly identify George W. Bush? How many times did it identify him as someone else?

# %% [markdown]
# ## Dropout test

# %%
from tensorflow.keras.layers import Dropout

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dropout(0.2))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 512)               1492480
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)

sns.set()
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 9ms/step - loss: 3.3636 - accuracy: 0.2225 - val_loss: 1.9207 - val_accuracy: 0.2100
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 2.0315 - accuracy: 0.2375 - val_loss: 1.8318 - val_accuracy: 0.2000
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6156 - accuracy: 0.3200 - val_loss: 1.4883 - val_accuracy: 0.3900
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4479 - accuracy: 0.3925 - val_loss: 1.5007 - val_accuracy: 0.3200
# Epoch 5/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4417 - accuracy: 0.4025 - val_loss: 1.4146 - val_accuracy: 0.5600
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3702 - accuracy: 0.4500 - val_loss: 1.3933 - val_accuracy: 0.4700
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4286 - accuracy: 0.4025 - val_loss: 1.5963 - val_accuracy: 0.3200
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3961 - accuracy: 0.4100 - val_loss: 1.4219 - val_accuracy: 0.4300
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2957 - accuracy: 0.5075 - val_loss: 1.3407 - val_accuracy: 0.5200
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2703 - accuracy: 0.4825 - val_loss: 1.3732 - val_accuracy: 0.3900
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2228 - accuracy: 0.5250 - val_loss: 1.3043 - val_accuracy: 0.5000
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.
100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2988 - accuracy: 0.9075 - val_loss: 0.6685 - val_accuracy: 0.8100
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2925 - accuracy: 0.9100 - val_loss: 0.6640 - val_accuracy: 0.8000
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2944 - accuracy: 0.8950 - val_loss: 0.6223 - val_accuracy: 0.8200
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2284 - accuracy: 0.9475 - val_loss: 0.6826 - val_accuracy: 0.8200
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2169 - accuracy: 0.9350 - val_loss: 0.6743 - val_accuracy: 0.7700
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2659 - accuracy: 0.9300 - val_loss: 0.7056 - val_accuracy: 0.7300
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2418 - accuracy: 0.9300 - val_loss: 0.7090 - val_accuracy: 0.7800
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2630 - accuracy: 0.9250 - val_loss: 0.8184 - val_accuracy: 0.7600
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2977 - accuracy: 0.9000 - val_loss: 0.7350 - val_accuracy: 0.7700
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2336 - accuracy: 0.9175 - val_loss: 0.6768 - val_accuracy: 0.7800
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1818 - accuracy: 0.9625 - val_loss: 0.6948 - val_accuracy: 0.8000
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2349 - accuracy: 0.9425 - val_loss: 0.6887 - val_accuracy: 0.7600
# Epoch 86/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.2649 - accuracy: 0.9325 - val_loss: 0.6080 - val_accuracy: 0.8300
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2265 - accuracy: 0.9425 - val_loss: 0.7981 - val_accuracy: 0.7900
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2806 - accuracy: 0.9075 - val_loss: 0.7341 - val_accuracy: 0.8100
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2536 - accuracy: 0.9125 - val_loss: 0.7386 - val_accuracy: 0.7200
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 0.9375 - val_loss: 0.8143 - val_accuracy: 0.7300
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2715 - accuracy: 0.9075 - val_loss: 0.7509 - val_accuracy: 0.8000
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2193 - accuracy: 0.9400 - val_loss: 0.6934 - val_accuracy: 0.8100
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2173 - accuracy: 0.9250 - val_loss: 0.8233 - val_accuracy: 0.7100
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1926 - accuracy: 0.9400 - val_loss: 0.6513 - val_accuracy: 0.7800
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2185 - accuracy: 0.9275 - val_loss: 0.6756 - val_accuracy: 0.8200
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2029 - accuracy: 0.9375 - val_loss: 0.6680 - val_accuracy: 0.8200
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1683 - accuracy: 0.9575 - val_loss: 0.6801 - val_accuracy: 0.7800
# Epoch 98/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.1648 - accuracy: 0.9575 - val_loss: 0.8651 - val_accuracy: 0.7200
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1668 - accuracy: 0.9550 - val_loss: 0.7598 - val_accuracy: 0.8100
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1833 - accuracy: 0.9475 - val_loss: 0.6639 - val_accuracy: 0.7800
# []

# %% [markdown]
# ## Callbacks test

# %%
from tensorflow.keras.callbacks import Callback

class StopCallback(Callback):
    accuracy_threshold = None
    
    def __init__(self, threshold):
        self.accuracy_threshold = threshold
        
    def on_epoch_end(self, epoch, logs=None):
        if (logs.get('val_accuracy') >= self.accuracy_threshold):
            self.model.stop_training = True

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

callback = StopCallback(0.8)
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20, callbacks=[callback])

sns.set()
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 9ms/step - loss: 3.2785 - accuracy: 0.1925 - val_loss: 1.5647 - val_accuracy: 0.2700
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5651 - accuracy: 0.3025 - val_loss: 1.6313 - val_accuracy: 0.2200
# Epoch 3/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.4759 - accuracy: 0.3300 - val_loss: 1.5896 - val_accuracy: 0.3200
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3280 - accuracy: 0.5000 - val_loss: 1.3479 - val_accuracy: 0.4800
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2288 - accuracy: 0.5350 - val_loss: 1.3158 - val_accuracy: 0.4300
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2424 - accuracy: 0.4950 - val_loss: 1.6116 - val_accuracy: 0.3300
# Epoch 7/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1338 - accuracy: 0.5575 - val_loss: 1.3353 - val_accuracy: 0.4000
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2067 - accuracy: 0.4900 - val_loss: 1.3823 - val_accuracy: 0.4000
# Epoch 9/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.0848 - accuracy: 0.5725 - val_loss: 1.1744 - val_accuracy: 0.5400
# Epoch 10/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.9602 - accuracy: 0.6425 - val_loss: 1.1804 - val_accuracy: 0.6300
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9604 - accuracy: 0.6700 - val_loss: 1.2319 - val_accuracy: 0.5600
# Epoch 12/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.8676 - accuracy: 0.7250 - val_loss: 1.0813 - val_accuracy: 0.5900
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8093 - accuracy: 0.7100 - val_loss: 1.1018 - val_accuracy: 0.6300
# Epoch 14/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7500 - accuracy: 0.8075 - val_loss: 1.0056 - val_accuracy: 0.6300
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7733 - accuracy: 0.7175 - val_loss: 1.2563 - val_accuracy: 0.5200
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7265 - accuracy: 0.7500 - val_loss: 1.1569 - val_accuracy: 0.5800
# Epoch 17/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7364 - accuracy: 0.7350 - val_loss: 0.9447 - val_accuracy: 0.6600
# Epoch 18/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7005 - accuracy: 0.7475 - val_loss: 0.8800 - val_accuracy: 0.6700
# Epoch 19/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6191 - accuracy: 0.8125 - val_loss: 1.0185 - val_accuracy: 0.6500
# Epoch 20/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6030 - accuracy: 0.8175 - val_loss: 1.1416 - val_accuracy: 0.5800
# Epoch 21/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.6835 - accuracy: 0.7825 - val_loss: 0.9252 - val_accuracy: 0.6700
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5465 - accuracy: 0.8175 - val_loss: 0.8619 - val_accuracy: 0.7500
# Epoch 23/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.5291 - accuracy: 0.8225 - val_loss: 0.9528 - val_accuracy: 0.6800
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7925 - val_loss: 1.2194 - val_accuracy: 0.5300
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5968 - accuracy: 0.7975 - val_loss: 0.9493 - val_accuracy: 0.7000
# Epoch 26/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.4440 - accuracy: 0.8700 - val_loss: 0.7368 - val_accuracy: 0.8000
# []

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

callback = EarlyStopping(monitor='val_accuracy', patience=10)
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20, callbacks=[callback])

sns.set()
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 9ms/step - loss: 3.7569 - accuracy: 0.2225 - val_loss: 1.8758 - val_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.7194 - accuracy: 0.2200 - val_loss: 1.5992 - val_accuracy: 0.2400
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6103 - accuracy: 0.2625 - val_loss: 1.4802 - val_accuracy: 0.2700
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4340 - accuracy: 0.3950 - val_loss: 1.4826 - val_accuracy: 0.4900
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3533 - accuracy: 0.5125 - val_loss: 1.5035 - val_accuracy: 0.4800
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3875 - accuracy: 0.4600 - val_loss: 1.4152 - val_accuracy: 0.3300
# Epoch 7/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.3125 - accuracy: 0.4750 - val_loss: 1.2881 - val_accuracy: 0.5300
# Epoch 8/100
# 20/20 [==============================] - 0s 5ms/step - loss: 1.1895 - accuracy: 0.5450 - val_loss: 1.2799 - val_accuracy: 0.4700
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0856 - accuracy: 0.6475 - val_loss: 1.2222 - val_accuracy: 0.5700
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0927 - accuracy: 0.5950 - val_loss: 1.1331 - val_accuracy: 0.6300
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9718 - accuracy: 0.6875 - val_loss: 1.0894 - val_accuracy: 0.6500
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9420 - accuracy: 0.7000 - val_loss: 1.2550 - val_accuracy: 0.5500
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9541 - accuracy: 0.6475 - val_loss: 1.0962 - val_accuracy: 0.6100
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8958 - accuracy: 0.7300 - val_loss: 1.1450 - val_accuracy: 0.5300
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8402 - accuracy: 0.7275 - val_loss: 0.9934 - val_accuracy: 0.7000
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7661 - accuracy: 0.7600 - val_loss: 1.1257 - val_accuracy: 0.5700
# Epoch 17/100
# 20/20 [==============================] - 0s 5ms/step - loss: 0.7129 - accuracy: 0.7900 - val_loss: 0.9646 - val_accuracy: 0.6400
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7044 - accuracy: 0.7650 - val_loss: 0.9560 - val_accuracy: 0.6500
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7633 - accuracy: 0.7225 - val_loss: 1.1576 - val_accuracy: 0.5900
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6757 - accuracy: 0.7725 - val_loss: 0.9840 - val_accuracy: 0.6600
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6226 - accuracy: 0.8050 - val_loss: 0.9654 - val_accuracy: 0.6600
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5886 - accuracy: 0.7950 - val_loss: 0.8441 - val_accuracy: 0.7100
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5350 - accuracy: 0.8400 - val_loss: 0.8166 - val_accuracy: 0.7200
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4937 - accuracy: 0.8625 - val_loss: 0.8540 - val_accuracy: 0.7300
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4850 - accuracy: 0.8525 - val_loss: 0.9327 - val_accuracy: 0.6800
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5280 - accuracy: 0.8250 - val_loss: 0.7658 - val_accuracy: 0.7600
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4664 - accuracy: 0.8675 - val_loss: 0.7519 - val_accuracy: 0.7900
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4709 - accuracy: 0.8625 - val_loss: 0.7914 - val_accuracy: 0.6800
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4527 - accuracy: 0.8725 - val_loss: 0.8230 - val_accuracy: 0.6600
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4293 - accuracy: 0.8875 - val_loss: 0.8247 - val_accuracy: 0.6800
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3973 - accuracy: 0.8725 - val_loss: 0.7087 - val_accuracy: 0.7600
# Epoch 32/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3771 - accuracy: 0.8900 - val_loss: 0.8131 - val_accuracy: 0.7400
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3580 - accuracy: 0.8950 - val_loss: 0.7128 - val_accuracy: 0.7600
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3768 - accuracy: 0.8850 - val_loss: 0.9005 - val_accuracy: 0.6800
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3642 - accuracy: 0.8850 - val_loss: 0.9134 - val_accuracy: 0.6900
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4193 - accuracy: 0.8400 - val_loss: 0.6737 - val_accuracy: 0.8000
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3375 - accuracy: 0.9000 - val_loss: 0.7951 - val_accuracy: 0.7400
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3217 - accuracy: 0.9100 - val_loss: 0.8816 - val_accuracy: 0.7000
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3055 - accuracy: 0.9400 - val_loss: 0.7196 - val_accuracy: 0.7400
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3547 - accuracy: 0.8925 - val_loss: 1.0433 - val_accuracy: 0.6300
# Epoch 41/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3354 - accuracy: 0.8900 - val_loss: 0.7356 - val_accuracy: 0.7400
# Epoch 42/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3198 - accuracy: 0.8775 - val_loss: 0.7042 - val_accuracy: 0.7300
# Epoch 43/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2882 - accuracy: 0.8950 - val_loss: 0.7007 - val_accuracy: 0.7900
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2315 - accuracy: 0.9500 - val_loss: 0.7090 - val_accuracy: 0.8000
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2457 - accuracy: 0.9225 - val_loss: 0.6754 - val_accuracy: 0.8200
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2004 - accuracy: 0.9625 - val_loss: 0.6994 - val_accuracy: 0.7900
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2210 - accuracy: 0.9425 - val_loss: 0.6554 - val_accuracy: 0.8000
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2057 - accuracy: 0.9525 - val_loss: 0.6725 - val_accuracy: 0.8200
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1893 - accuracy: 0.9650 - val_loss: 0.8254 - val_accuracy: 0.7500
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2558 - accuracy: 0.9150 - val_loss: 0.7879 - val_accuracy: 0.7900
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2027 - accuracy: 0.9575 - val_loss: 0.7548 - val_accuracy: 0.7700
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1776 - accuracy: 0.9650 - val_loss: 0.8445 - val_accuracy: 0.7500
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2496 - accuracy: 0.9125 - val_loss: 0.7066 - val_accuracy: 0.7600
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2263 - accuracy: 0.9325 - val_loss: 0.7405 - val_accuracy: 0.7800
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1995 - accuracy: 0.9425 - val_loss: 0.7855 - val_accuracy: 0.7900
# []

# %%
from tensorflow.keras.callbacks import EarlyStopping

model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

callback = EarlyStopping(monitor='loss', patience=10)
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20, callbacks=[callback])

sns.set()
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 9ms/step - loss: 3.5378 - accuracy: 0.1925 - val_loss: 2.0355 - val_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6846 - accuracy: 0.2175 - val_loss: 1.5264 - val_accuracy: 0.3800
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4776 - accuracy: 0.3275 - val_loss: 1.6744 - val_accuracy: 0.3000
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4981 - accuracy: 0.3625 - val_loss: 1.3761 - val_accuracy: 0.4800
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2887 - accuracy: 0.5300 - val_loss: 1.3742 - val_accuracy: 0.5000
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1870 - accuracy: 0.5900 - val_loss: 1.3873 - val_accuracy: 0.3300
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1994 - accuracy: 0.5225 - val_loss: 1.3594 - val_accuracy: 0.4100
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1354 - accuracy: 0.5900 - val_loss: 1.2224 - val_accuracy: 0.5400
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0400 - accuracy: 0.6050 - val_loss: 1.1783 - val_accuracy: 0.5300
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0233 - accuracy: 0.6350 - val_loss: 1.1239 - val_accuracy: 0.6100
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9245 - accuracy: 0.6850 - val_loss: 1.0632 - val_accuracy: 0.6400
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8367 - accuracy: 0.7325 - val_loss: 1.2614 - val_accuracy: 0.4700
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8838 - accuracy: 0.6850 - val_loss: 1.1580 - val_accuracy: 0.5900
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8009 - accuracy: 0.7325 - val_loss: 1.0044 - val_accuracy: 0.6300
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8060 - accuracy: 0.7325 - val_loss: 1.1935 - val_accuracy: 0.5200
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8043 - accuracy: 0.7175 - val_loss: 1.2163 - val_accuracy: 0.5200
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7401 - accuracy: 0.7575 - val_loss: 1.1445 - val_accuracy: 0.5400
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6776 - accuracy: 0.7700 - val_loss: 1.1472 - val_accuracy: 0.5300
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6252 - accuracy: 0.8200 - val_loss: 0.9086 - val_accuracy: 0.7200
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5708 - accuracy: 0.8325 - val_loss: 0.8361 - val_accuracy: 0.7500
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5352 - accuracy: 0.8325 - val_loss: 0.7897 - val_accuracy: 0.7400
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5661 - accuracy: 0.8350 - val_loss: 1.0494 - val_accuracy: 0.6800
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6085 - accuracy: 0.8000 - val_loss: 0.7676 - val_accuracy: 0.7700
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5113 - accuracy: 0.8550 - val_loss: 0.8285 - val_accuracy: 0.7300
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4509 - accuracy: 0.8725 - val_loss: 0.8325 - val_accuracy: 0.7200
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5204 - accuracy: 0.8175 - val_loss: 0.8859 - val_accuracy: 0.6500
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4444 - accuracy: 0.8725 - val_loss: 0.7597 - val_accuracy: 0.7200
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3796 - accuracy: 0.8975 - val_loss: 0.7971 - val_accuracy: 0.6700
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3939 - accuracy: 0.8900 - val_loss: 0.7899 - val_accuracy: 0.7300
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3762 - accuracy: 0.8875 - val_loss: 0.8472 - val_accuracy: 0.6800
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4643 - accuracy: 0.8250 - val_loss: 0.8717 - val_accuracy: 0.7300
# Epoch 32/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4353 - accuracy: 0.8575 - val_loss: 0.9142 - val_accuracy: 0.6900
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3722 - accuracy: 0.8675 - val_loss: 0.8218 - val_accuracy: 0.7300
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3504 - accuracy: 0.8925 - val_loss: 0.7198 - val_accuracy: 0.7600
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2908 - accuracy: 0.9250 - val_loss: 0.7096 - val_accuracy: 0.7800
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2784 - accuracy: 0.9250 - val_loss: 0.7094 - val_accuracy: 0.7200
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3104 - accuracy: 0.9125 - val_loss: 0.9032 - val_accuracy: 0.6700
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4020 - accuracy: 0.8800 - val_loss: 0.8837 - val_accuracy: 0.6900
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3955 - accuracy: 0.8725 - val_loss: 0.8448 - val_accuracy: 0.7500
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3533 - accuracy: 0.8875 - val_loss: 0.7841 - val_accuracy: 0.7800
# Epoch 41/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2846 - accuracy: 0.9225 - val_loss: 0.8451 - val_accuracy: 0.7400
# Epoch 42/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2539 - accuracy: 0.9350 - val_loss: 0.7689 - val_accuracy: 0.7700
# Epoch 43/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2644 - accuracy: 0.9175 - val_loss: 0.6696 - val_accuracy: 0.8300
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2427 - accuracy: 0.9275 - val_loss: 0.6398 - val_accuracy: 0.7700
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2042 - accuracy: 0.9425 - val_loss: 0.6385 - val_accuracy: 0.8000
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2125 - accuracy: 0.9475 - val_loss: 0.9200 - val_accuracy: 0.7000
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2525 - accuracy: 0.9175 - val_loss: 0.7677 - val_accuracy: 0.7100
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2464 - accuracy: 0.9225 - val_loss: 0.6523 - val_accuracy: 0.8100
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2054 - accuracy: 0.9400 - val_loss: 0.7126 - val_accuracy: 0.8000
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9625 - val_loss: 0.7382 - val_accuracy: 0.7900
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2042 - accuracy: 0.9350 - val_loss: 1.0521 - val_accuracy: 0.7400
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2762 - accuracy: 0.9125 - val_loss: 0.6390 - val_accuracy: 0.8000
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1625 - accuracy: 0.9650 - val_loss: 0.7272 - val_accuracy: 0.7500
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2044 - accuracy: 0.9425 - val_loss: 0.7777 - val_accuracy: 0.7700
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2537 - accuracy: 0.9125 - val_loss: 0.9106 - val_accuracy: 0.7200
# Epoch 56/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2028 - accuracy: 0.9300 - val_loss: 0.7995 - val_accuracy: 0.7900
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1728 - accuracy: 0.9550 - val_loss: 0.7383 - val_accuracy: 0.7900
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1959 - accuracy: 0.9450 - val_loss: 0.7579 - val_accuracy: 0.7700
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1646 - accuracy: 0.9475 - val_loss: 0.7082 - val_accuracy: 0.8100
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1181 - accuracy: 0.9800 - val_loss: 0.7606 - val_accuracy: 0.7600
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9650 - val_loss: 0.7144 - val_accuracy: 0.7900
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.9550 - val_loss: 0.9120 - val_accuracy: 0.6800
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1276 - accuracy: 0.9725 - val_loss: 0.7685 - val_accuracy: 0.7800
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1121 - accuracy: 0.9875 - val_loss: 0.7225 - val_accuracy: 0.7900
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1078 - accuracy: 0.9725 - val_loss: 0.6851 - val_accuracy: 0.7700
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0862 - accuracy: 0.9900 - val_loss: 0.7776 - val_accuracy: 0.7500
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1050 - accuracy: 0.9850 - val_loss: 0.6374 - val_accuracy: 0.8000
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1053 - accuracy: 0.9875 - val_loss: 0.7480 - val_accuracy: 0.7000
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1328 - accuracy: 0.9675 - val_loss: 0.7262 - val_accuracy: 0.8000
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1050 - accuracy: 0.9750 - val_loss: 0.7032 - val_accuracy: 0.8200
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1273 - accuracy: 0.9650 - val_loss: 0.7105 - val_accuracy: 0.8000
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0708 - accuracy: 0.9950 - val_loss: 0.7402 - val_accuracy: 0.7500
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0902 - accuracy: 0.9825 - val_loss: 0.7914 - val_accuracy: 0.7500
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1390 - accuracy: 0.9625 - val_loss: 0.6775 - val_accuracy: 0.7600
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0909 - accuracy: 0.9800 - val_loss: 0.7147 - val_accuracy: 0.7800
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0930 - accuracy: 0.9900 - val_loss: 0.7124 - val_accuracy: 0.8000
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0725 - accuracy: 0.9950 - val_loss: 0.6322 - val_accuracy: 0.8200
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0617 - accuracy: 0.9925 - val_loss: 0.6578 - val_accuracy: 0.8200
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0506 - accuracy: 1.0000 - val_loss: 0.6235 - val_accuracy: 0.8400
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0508 - accuracy: 0.9975 - val_loss: 0.7000 - val_accuracy: 0.8100
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0819 - accuracy: 0.9850 - val_loss: 0.8930 - val_accuracy: 0.7700
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0899 - accuracy: 0.9850 - val_loss: 0.6854 - val_accuracy: 0.7400
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9900 - val_loss: 0.7356 - val_accuracy: 0.8000
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0868 - accuracy: 0.9850 - val_loss: 0.7019 - val_accuracy: 0.8100
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.8894 - val_accuracy: 0.7300
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 0.9950 - val_loss: 0.6699 - val_accuracy: 0.8200
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0428 - accuracy: 0.9975 - val_loss: 0.6516 - val_accuracy: 0.7900
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 0.9950 - val_loss: 0.7713 - val_accuracy: 0.8100
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.6766 - val_accuracy: 0.8200
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0446 - accuracy: 0.9925 - val_loss: 0.7378 - val_accuracy: 0.8200
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0417 - accuracy: 1.0000 - val_loss: 0.8098 - val_accuracy: 0.8200
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0362 - accuracy: 1.0000 - val_loss: 0.7134 - val_accuracy: 0.8200
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0420 - accuracy: 0.9925 - val_loss: 0.7755 - val_accuracy: 0.7600
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 1.0000 - val_loss: 0.6827 - val_accuracy: 0.8400
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0344 - accuracy: 1.0000 - val_loss: 0.7862 - val_accuracy: 0.8100
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0291 - accuracy: 1.0000 - val_loss: 0.7752 - val_accuracy: 0.8000
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0439 - accuracy: 0.9950 - val_loss: 0.7350 - val_accuracy: 0.8000
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0500 - accuracy: 0.9975 - val_loss: 0.7108 - val_accuracy: 0.8300
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000 - val_loss: 0.8264 - val_accuracy: 0.7900
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 1.0000 - val_loss: 0.6760 - val_accuracy: 0.8400
# []

# %%
y_pred = model.predict(x_test)
model.evaluate(x_test, y_test)
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.7368 - accuracy: 0.8000
# [0.7368257641792297, 0.800000011920929]
