# %%
import pandas as pd
from sklearn.datasets import fetch_lfw_people
 
faces = fetch_lfw_people(min_faces_per_person=100)
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)
  
faces = fetch_lfw_people(min_faces_per_person=100)
print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
  
fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %%
from collections import Counter
import seaborn as sns
sns.set()

counts = Counter(faces.target)
names = {}
  
for key in counts.keys():
    names[faces.target_names[key]] = counts[key]
  
df = pd.DataFrame.from_dict(names, orient='index')
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import numpy as np

mask = np.zeros(faces.target.shape, dtype=bool)
  
for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
      
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %%
from sklearn.model_selection import train_test_split
 
face_images = x_faces / 255
x_train, x_test, y_train, y_test = train_test_split(face_images, y_faces,
                                                    train_size=0.8,
                                                    stratify=y_faces,
                                                    random_state=0)

# %%
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
 
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dropout(0.2))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1492480
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test),
                 epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 10ms/step - loss: 3.1944 - accuracy: 0.2125 - val_loss: 1.8147 - val_accuracy: 0.2800
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.8803 - accuracy: 0.2300 - val_loss: 1.5674 - val_accuracy: 0.3800
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5825 - accuracy: 0.2700 - val_loss: 1.5225 - val_accuracy: 0.3300
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4969 - accuracy: 0.3800 - val_loss: 1.4773 - val_accuracy: 0.5600
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4455 - accuracy: 0.3975 - val_loss: 1.4638 - val_accuracy: 0.3000
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4680 - accuracy: 0.3600 - val_loss: 1.4342 - val_accuracy: 0.4300
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3783 - accuracy: 0.4550 - val_loss: 1.3996 - val_accuracy: 0.4400
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3247 - accuracy: 0.4875 - val_loss: 1.3592 - val_accuracy: 0.4500
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2993 - accuracy: 0.4900 - val_loss: 1.2687 - val_accuracy: 0.6300
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2701 - accuracy: 0.5100 - val_loss: 1.2460 - val_accuracy: 0.6100
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2140 - accuracy: 0.5650 - val_loss: 1.2163 - val_accuracy: 0.6000
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1495 - accuracy: 0.5875 - val_loss: 1.1706 - val_accuracy: 0.6300
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1492 - accuracy: 0.5825 - val_loss: 1.2527 - val_accuracy: 0.4400
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0949 - accuracy: 0.6025 - val_loss: 1.1965 - val_accuracy: 0.5000
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.
100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6039 - accuracy: 0.8025 - val_loss: 0.6944 - val_accuracy: 0.7700
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4700 - accuracy: 0.8375 - val_loss: 0.7922 - val_accuracy: 0.7400
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4734 - accuracy: 0.8650 - val_loss: 0.6292 - val_accuracy: 0.7700
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4345 - accuracy: 0.8650 - val_loss: 0.7279 - val_accuracy: 0.7000
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5166 - accuracy: 0.8150 - val_loss: 0.6727 - val_accuracy: 0.7700
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4515 - accuracy: 0.8525 - val_loss: 0.6479 - val_accuracy: 0.7500
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4508 - accuracy: 0.8700 - val_loss: 0.6679 - val_accuracy: 0.6900
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4137 - accuracy: 0.8725 - val_loss: 0.6519 - val_accuracy: 0.7600
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4008 - accuracy: 0.8875 - val_loss: 0.7832 - val_accuracy: 0.7400
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4242 - accuracy: 0.8700 - val_loss: 0.6271 - val_accuracy: 0.7900
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4190 - accuracy: 0.8900 - val_loss: 0.6508 - val_accuracy: 0.7700
# Epoch 56/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3936 - accuracy: 0.8875 - val_loss: 0.7941 - val_accuracy: 0.7500
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3878 - accuracy: 0.8825 - val_loss: 0.6346 - val_accuracy: 0.7800
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3462 - accuracy: 0.9050 - val_loss: 0.6667 - val_accuracy: 0.7500
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3581 - accuracy: 0.8825 - val_loss: 0.6267 - val_accuracy: 0.7700
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3479 - accuracy: 0.8825 - val_loss: 0.5817 - val_accuracy: 0.7700
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3385 - accuracy: 0.9125 - val_loss: 0.6338 - val_accuracy: 0.7800
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3015 - accuracy: 0.9075 - val_loss: 0.5759 - val_accuracy: 0.7700
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3277 - accuracy: 0.8900 - val_loss: 0.6993 - val_accuracy: 0.7600
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3292 - accuracy: 0.8925 - val_loss: 0.5732 - val_accuracy: 0.7900
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3273 - accuracy: 0.9050 - val_loss: 0.5378 - val_accuracy: 0.8000
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3897 - accuracy: 0.8550 - val_loss: 0.7701 - val_accuracy: 0.7200
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3812 - accuracy: 0.8700 - val_loss: 0.5605 - val_accuracy: 0.7900
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3650 - accuracy: 0.8700 - val_loss: 0.5976 - val_accuracy: 0.7800
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2957 - accuracy: 0.9075 - val_loss: 0.5832 - val_accuracy: 0.7800
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3261 - accuracy: 0.8975 - val_loss: 0.6781 - val_accuracy: 0.7600
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3345 - accuracy: 0.8925 - val_loss: 0.7480 - val_accuracy: 0.7700
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3338 - accuracy: 0.8800 - val_loss: 0.7108 - val_accuracy: 0.7500
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3665 - accuracy: 0.8925 - val_loss: 0.6050 - val_accuracy: 0.7800
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2918 - accuracy: 0.9150 - val_loss: 0.5512 - val_accuracy: 0.8000
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2294 - accuracy: 0.9300 - val_loss: 0.5762 - val_accuracy: 0.8300
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2562 - accuracy: 0.9300 - val_loss: 0.5234 - val_accuracy: 0.7900
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3034 - accuracy: 0.9025 - val_loss: 0.6239 - val_accuracy: 0.7900
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2164 - accuracy: 0.9550 - val_loss: 0.7166 - val_accuracy: 0.7600
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2714 - accuracy: 0.9050 - val_loss: 0.7100 - val_accuracy: 0.7200
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2854 - accuracy: 0.9125 - val_loss: 0.6322 - val_accuracy: 0.7700
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2875 - accuracy: 0.9000 - val_loss: 0.6342 - val_accuracy: 0.8000
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2575 - accuracy: 0.9175 - val_loss: 0.6412 - val_accuracy: 0.7500
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2293 - accuracy: 0.9300 - val_loss: 0.5766 - val_accuracy: 0.8000
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2239 - accuracy: 0.9500 - val_loss: 0.6442 - val_accuracy: 0.7900
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2641 - accuracy: 0.9100 - val_loss: 0.6725 - val_accuracy: 0.7700
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2761 - accuracy: 0.9075 - val_loss: 0.5338 - val_accuracy: 0.8400
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2590 - accuracy: 0.9200 - val_loss: 0.5766 - val_accuracy: 0.8100
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2922 - accuracy: 0.9100 - val_loss: 0.5433 - val_accuracy: 0.7900
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2364 - accuracy: 0.9400 - val_loss: 0.5361 - val_accuracy: 0.7700
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2903 - accuracy: 0.9125 - val_loss: 0.5424 - val_accuracy: 0.8000
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2438 - accuracy: 0.9225 - val_loss: 0.8514 - val_accuracy: 0.7100
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2846 - accuracy: 0.9100 - val_loss: 0.5334 - val_accuracy: 0.7900
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2830 - accuracy: 0.8925 - val_loss: 0.5497 - val_accuracy: 0.8000
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3109 - accuracy: 0.8850 - val_loss: 0.6535 - val_accuracy: 0.7900
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3325 - accuracy: 0.8925 - val_loss: 0.6546 - val_accuracy: 0.8000
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2930 - accuracy: 0.9025 - val_loss: 0.5543 - val_accuracy: 0.8300
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2160 - accuracy: 0.9400 - val_loss: 0.7178 - val_accuracy: 0.7600
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2094 - accuracy: 0.9425 - val_loss: 0.5740 - val_accuracy: 0.7900
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2290 - accuracy: 0.9175 - val_loss: 0.6716 - val_accuracy: 0.7900
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2035 - accuracy: 0.9400 - val_loss: 0.5573 - val_accuracy: 0.8200

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %%
from sklearn.metrics import ConfusionMatrixDisplay as cmd

sns.reset_orig()
y_pred = model.predict(x_test)
fig, ax = plt.subplots(figsize=(5, 5))
ax.grid(False)

cmd.from_predictions(y_test, y_pred.argmax(axis=1),
                     display_labels=faces.target_names, colorbar=False,
                     cmap='Blues', xticks_rotation='vertical', ax=ax)
