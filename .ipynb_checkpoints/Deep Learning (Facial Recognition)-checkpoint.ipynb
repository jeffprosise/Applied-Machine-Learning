# %% [markdown]
# # Facial Recognition via Deep Learning
#
# [Deep learning](https://en.wikipedia.org/wiki/Deep_learning) is a branch of machine learning that relies primarily on [neural networks](https://en.wikipedia.org/wiki/Neural_network). Neural networks are built with libraries such as [TensorFlow](https://www.tensorflow.org/) and [Keras](https://keras.io/). The latter is an open-source Python library that dramatically simplifies the building of neural networks. Under the hood, it uses TensorFlow and other frameworks to do the heavy lifting. With Keras, you can build sophisticated neural networks with just a few lines of code and train them to classify images, analyze text for sentiment, and perform other tasks at which deep learning excels.
#
# Let's use Keras to build a neural network that recognizes faces. You will train it with images from the famous [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset. Along the way, you will learn the basics of building, training, and evaluating neural networks.

# %% [markdown]
# ## Load the dataset
#
# The first step is to import facial images from the dataset. LFW contains more than 13,000 facial images collected from the Web. Of the more than 5,000 people represented in the dataset, 1,680 have two or more facial images, while only five have 100 or more. We'll set the minimum number of faces per person to 100, which means that five sets of faces corresponding to five famous people will be imported. Each facial image is labeled with the name of the person that the face belongs to.

# %%
import pandas as pd
from sklearn.datasets import fetch_lfw_people

faces = fetch_lfw_people(min_faces_per_person=100)
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)

print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1,140 facial images were loaded. Each image measures 47 x 62 pixels for a total of 2,914 pixels per image. That means we're working with a model with 2,914 feature columns. Use the following code to show the first 24 images in the dataset and the people to whom the faces belong.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# Check the balance in the dataset by generating a histogram showing how many facial images were imported for each person.

# %%
from collections import Counter
counts = Counter(faces.target)
names = {}

for key in counts.keys():
    names[faces.target_names[key]] = counts[key]

df = pd.DataFrame.from_dict(names, orient='index')
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The dataset is not very well balanced, and that's a concern because classification models are best trained with balanced datasets. Use the following code to build a dataset containing 100 images of each person.

# %%
import numpy as np

mask = np.zeros(faces.target.shape, dtype=bool)

for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
    
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %% [markdown]
# The next step is to normalize pixel values by dividing them by 255, and to convert the target values (the 0-based indices identifying the person that belongs to a face) into categorical values by [one-hot-encoding](https://hackernoon.com/what-is-one-hot-encoding-why-and-when-do-you-have-to-use-it-e3c6186d008f) them. After that, we'll split the data for training and testing. Rather than allow Keras to do the splitting, we'll use Scikit-learn so we can validate the network with data it hasn't seen before.

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

face_images = x_faces / 255
face_labels = to_categorical(y_faces)
                             
x_train, x_test, y_train, y_test = train_test_split(face_images, face_labels, train_size=0.8, stratify=face_labels, random_state=0)

# %% [markdown]
# ## Build and train a neural network
#
# Start by using Keras to build and train a neural network containing one hidden layer with 512 neurons. We'll use `categorical_crossentropy` as the loss function and a `softmax` output layer since this is a multiclass classification task. We will also use `adam` as the optimization algorithm. Rather than use a fixed learning rate, `adam` varies the learning rate as training proceeds so the network learns faster in the early stages of training and (hopefully) converges more accurately toward a solution in later stages.

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
 
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1492480
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now train the network and plot the training and validation accuracy.

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 10ms/step - loss: 2.7867 - accuracy: 0.2375 - val_loss: 1.7704 - val_accuracy: 0.2000
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.5541 - accuracy: 0.3125 - val_loss: 1.6527 - val_accuracy: 0.3100
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4764 - accuracy: 0.3675 - val_loss: 1.3811 - val_accuracy: 0.4900
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2717 - accuracy: 0.4875 - val_loss: 1.5000 - val_accuracy: 0.2900
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.2611 - accuracy: 0.4625 - val_loss: 1.2812 - val_accuracy: 0.4800
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0937 - accuracy: 0.6525 - val_loss: 1.1584 - val_accuracy: 0.6100
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0814 - accuracy: 0.5975 - val_loss: 1.1142 - val_accuracy: 0.6300
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.0008 - accuracy: 0.6625 - val_loss: 1.2658 - val_accuracy: 0.5700
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9363 - accuracy: 0.6600 - val_loss: 1.1636 - val_accuracy: 0.4900
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8497 - accuracy: 0.7325 - val_loss: 1.1275 - val_accuracy: 0.5700
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8892 - accuracy: 0.6875 - val_loss: 1.2896 - val_accuracy: 0.4300
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8951 - accuracy: 0.6225 - val_loss: 1.2611 - val_accuracy: 0.5200
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8167 - accuracy: 0.7050 - val_loss: 0.9056 - val_accuracy: 0.6800
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.7950 - val_loss: 0.9844 - val_accuracy: 0.6000
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6721 - accuracy: 0.8000 - val_loss: 1.0061 - val_accuracy: 0.6400
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6515 - accuracy: 0.7575 - val_loss: 0.9734 - val_accuracy: 0.6400
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6133 - accuracy: 0.8050 - val_loss: 1.0240 - val_accuracy: 0.6400
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7562 - accuracy: 0.7275 - val_loss: 0.9588 - val_accuracy: 0.6300
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5282 - accuracy: 0.8450 - val_loss: 0.9780 - val_accuracy: 0.6600
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5242 - accuracy: 0.8375 - val_loss: 0.8299 - val_accuracy: 0.7000
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4812 - accuracy: 0.8575 - val_loss: 0.7586 - val_accuracy: 0.7300
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4614 - accuracy: 0.8675 - val_loss: 0.8023 - val_accuracy: 0.7400
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5055 - accuracy: 0.8200 - val_loss: 0.9779 - val_accuracy: 0.6200
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4496 - accuracy: 0.8725 - val_loss: 0.7573 - val_accuracy: 0.7500
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3910 - accuracy: 0.8950 - val_loss: 0.8491 - val_accuracy: 0.7100
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5143 - accuracy: 0.8350 - val_loss: 0.8164 - val_accuracy: 0.7500
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3741 - accuracy: 0.8875 - val_loss: 0.7375 - val_accuracy: 0.7600
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4647 - accuracy: 0.8350 - val_loss: 0.7401 - val_accuracy: 0.7500
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4249 - accuracy: 0.8775 - val_loss: 0.7209 - val_accuracy: 0.7700
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3267 - accuracy: 0.9050 - val_loss: 0.6644 - val_accuracy: 0.7700
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2841 - accuracy: 0.9325 - val_loss: 0.7332 - val_accuracy: 0.7900
# Epoch 32/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3084 - accuracy: 0.9150 - val_loss: 1.0656 - val_accuracy: 0.6700
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3818 - accuracy: 0.8750 - val_loss: 0.9103 - val_accuracy: 0.6600
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3174 - accuracy: 0.9125 - val_loss: 0.7607 - val_accuracy: 0.7000
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2549 - accuracy: 0.9375 - val_loss: 0.6489 - val_accuracy: 0.8200
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2837 - accuracy: 0.9000 - val_loss: 0.6866 - val_accuracy: 0.8000
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2641 - accuracy: 0.9275 - val_loss: 0.8997 - val_accuracy: 0.7200
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3242 - accuracy: 0.8800 - val_loss: 0.7248 - val_accuracy: 0.8100
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2242 - accuracy: 0.9325 - val_loss: 0.7720 - val_accuracy: 0.7500
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2785 - accuracy: 0.9075 - val_loss: 0.9199 - val_accuracy: 0.7000
# Epoch 41/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2755 - accuracy: 0.9225 - val_loss: 0.7336 - val_accuracy: 0.7500
# Epoch 42/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2665 - accuracy: 0.9100 - val_loss: 0.9538 - val_accuracy: 0.7000
# Epoch 43/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3103 - accuracy: 0.8950 - val_loss: 0.6898 - val_accuracy: 0.7500
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2459 - accuracy: 0.9375 - val_loss: 0.7136 - val_accuracy: 0.7800
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2378 - accuracy: 0.9225 - val_loss: 1.1240 - val_accuracy: 0.6700
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2209 - accuracy: 0.9325 - val_loss: 0.7420 - val_accuracy: 0.7900
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2242 - accuracy: 0.9400 - val_loss: 0.6547 - val_accuracy: 0.8100
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2124 - accuracy: 0.9400 - val_loss: 0.7128 - val_accuracy: 0.8000
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1312 - accuracy: 0.9825 - val_loss: 0.6920 - val_accuracy: 0.8000
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1327 - accuracy: 0.9825 - val_loss: 0.6587 - val_accuracy: 0.7800
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1357 - accuracy: 0.9700 - val_loss: 0.6712 - val_accuracy: 0.7600
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9625 - val_loss: 0.9590 - val_accuracy: 0.6800
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2426 - accuracy: 0.9225 - val_loss: 0.7646 - val_accuracy: 0.7800
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1718 - accuracy: 0.9550 - val_loss: 0.8669 - val_accuracy: 0.7400
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1692 - accuracy: 0.9525 - val_loss: 1.1458 - val_accuracy: 0.6600
# Epoch 56/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2048 - accuracy: 0.9275 - val_loss: 0.6251 - val_accuracy: 0.8000
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1686 - accuracy: 0.9550 - val_loss: 0.7129 - val_accuracy: 0.7800
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1527 - accuracy: 0.9650 - val_loss: 0.6773 - val_accuracy: 0.8300
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1414 - accuracy: 0.9600 - val_loss: 0.7249 - val_accuracy: 0.8100
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0991 - accuracy: 0.9825 - val_loss: 0.6650 - val_accuracy: 0.8200
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 0.9775 - val_loss: 0.6466 - val_accuracy: 0.8200
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0880 - accuracy: 0.9950 - val_loss: 0.7441 - val_accuracy: 0.7900
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1462 - accuracy: 0.9650 - val_loss: 0.7023 - val_accuracy: 0.8100
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1388 - accuracy: 0.9700 - val_loss: 0.7646 - val_accuracy: 0.7800
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1165 - accuracy: 0.9750 - val_loss: 0.8458 - val_accuracy: 0.7600
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1173 - accuracy: 0.9750 - val_loss: 0.8992 - val_accuracy: 0.7400
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1069 - accuracy: 0.9725 - val_loss: 0.7085 - val_accuracy: 0.8200
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1276 - accuracy: 0.9700 - val_loss: 0.7235 - val_accuracy: 0.7900
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1373 - accuracy: 0.9600 - val_loss: 1.0929 - val_accuracy: 0.7100
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9650 - val_loss: 0.7833 - val_accuracy: 0.7800
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0969 - accuracy: 0.9700 - val_loss: 0.7729 - val_accuracy: 0.7900
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0668 - accuracy: 0.9950 - val_loss: 0.7025 - val_accuracy: 0.7900
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0745 - accuracy: 0.9950 - val_loss: 0.8145 - val_accuracy: 0.7600
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0598 - accuracy: 0.9925 - val_loss: 0.7307 - val_accuracy: 0.8100
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0499 - accuracy: 1.0000 - val_loss: 0.7135 - val_accuracy: 0.8200
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0656 - accuracy: 0.9875 - val_loss: 0.8072 - val_accuracy: 0.7300
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0813 - accuracy: 0.9850 - val_loss: 0.8450 - val_accuracy: 0.7600
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2256 - accuracy: 0.9225 - val_loss: 0.7686 - val_accuracy: 0.7800
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1809 - accuracy: 0.9275 - val_loss: 0.6554 - val_accuracy: 0.8100
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0705 - accuracy: 0.9900 - val_loss: 0.6998 - val_accuracy: 0.8100
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0595 - accuracy: 0.9950 - val_loss: 0.6851 - val_accuracy: 0.8400
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0695 - accuracy: 0.9800 - val_loss: 0.6668 - val_accuracy: 0.8000
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9925 - val_loss: 0.8335 - val_accuracy: 0.7900
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0655 - accuracy: 0.9850 - val_loss: 0.7922 - val_accuracy: 0.7900
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0543 - accuracy: 1.0000 - val_loss: 0.7343 - val_accuracy: 0.7900
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0342 - accuracy: 1.0000 - val_loss: 0.7288 - val_accuracy: 0.7900
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 0.9925 - val_loss: 0.7012 - val_accuracy: 0.8100
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0349 - accuracy: 1.0000 - val_loss: 0.8546 - val_accuracy: 0.7700
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.8282 - val_accuracy: 0.7600
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0394 - accuracy: 0.9975 - val_loss: 0.7522 - val_accuracy: 0.8300
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0635 - accuracy: 0.9875 - val_loss: 0.7720 - val_accuracy: 0.8000
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0518 - accuracy: 0.9950 - val_loss: 0.6982 - val_accuracy: 0.8500
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0275 - accuracy: 1.0000 - val_loss: 0.6891 - val_accuracy: 0.8400
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0387 - accuracy: 0.9925 - val_loss: 0.7370 - val_accuracy: 0.8300
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0285 - accuracy: 1.0000 - val_loss: 0.6981 - val_accuracy: 0.8400
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0306 - accuracy: 1.0000 - val_loss: 0.7799 - val_accuracy: 0.8000
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.6986 - val_accuracy: 0.8100
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0298 - accuracy: 0.9975 - val_loss: 0.7577 - val_accuracy: 0.7800
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0309 - accuracy: 0.9975 - val_loss: 0.6719 - val_accuracy: 0.8200
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0311 - accuracy: 1.0000 - val_loss: 0.8341 - val_accuracy: 0.7800
# []

# %% [markdown]
# Finally, use the test data to generate a confusion matrix to visualize how the network performs.

# %%
from sklearn.metrics import ConfusionMatrixDisplay as cmd

sns.reset_orig()
y_predicted = model.predict(x_test)
fig, ax = plt.subplots(figsize=(6, 6))
ax.grid(False)

cmd.from_predictions(y_test.argmax(axis=1), y_predicted.argmax(axis=1),
                     display_labels=faces.target_names, colorbar=False,
                     cmap='Blues', xticks_rotation='vertical', ax=ax)

# %% [markdown]
# How many times did the model correctly identify George W. Bush? How many times did it identify him as someone else?
