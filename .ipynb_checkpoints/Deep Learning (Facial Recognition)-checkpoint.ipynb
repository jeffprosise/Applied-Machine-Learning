# %% [markdown]
# # Facial Recognition via Deep Learning
#
# [Deep learning](https://en.wikipedia.org/wiki/Deep_learning) is a branch of machine learning that relies primarily on [neural networks](https://en.wikipedia.org/wiki/Neural_network). Neural networks are built with libraries such as [TensorFlow](https://www.tensorflow.org/) and [Keras](https://keras.io/). The latter is an open-source Python library that dramatically simplifies the building of neural networks. Under the hood, it uses TensorFlow and other frameworks to do the heavy lifting. With Keras, you can build sophisticated neural networks with just a few lines of code and train them to classify images, analyze text for sentiment, and perform other tasks at which deep learning excels.
#
# Let's use Keras to build a neural network that recognizes faces. You will train it with images from the famous [Labeled Faces in the Wild](http://vis-www.cs.umass.edu/lfw/) (LFW) dataset. Along the way, you will learn the basics of building, training, and evaluating neural networks.

# %% [markdown]
# ## Load the dataset
#
# The first step is to import facial images from the dataset. LFW contains more than 13,000 facial images collected from the Web. Of the more than 5,000 people represented in the dataset, 1,680 have two or more facial images, while only five have 100 or more. We'll set the minimum number of faces per person to 100, which means that five sets of faces corresponding to five famous people will be imported. Each facial image is labeled with the name of the person that the face belongs to.

# %%
import pandas as pd
from sklearn.datasets import fetch_lfw_people

faces = fetch_lfw_people(min_faces_per_person=100)
image_count = faces.images.shape[0]
image_height = faces.images.shape[1]
image_width = faces.images.shape[2]
class_count = len(faces.target_names)

print(faces.target_names)
print(faces.images.shape)
# Out:
# ['Colin Powell' 'Donald Rumsfeld' 'George W Bush' 'Gerhard Schroeder'
#  'Tony Blair']
# (1140, 62, 47)

# %% [markdown]
# In total, 1,140 facial images were loaded. Each image measures 47 x 62 pixels for a total of 2,914 pixels per image. That means we're working with a model with 2,914 feature columns. Use the following code to show the first 24 images in the dataset and the people to whom the faces belong.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(3, 8, figsize=(18, 10))
for i, axi in enumerate(ax.flat):
    axi.imshow(faces.images[i], cmap='gist_gray')
    axi.set(xticks=[], yticks=[], xlabel=faces.target_names[faces.target[i]])

# %% [markdown]
# Check the balance in the dataset by generating a histogram showing how many facial images were imported for each person.

# %%
from collections import Counter
import seaborn as sns
sns.set()

counts = Counter(faces.target)
names = {}

for key in counts.keys():
    names[faces.target_names[key]] = counts[key]

df = pd.DataFrame.from_dict(names, orient='index')
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The dataset is not very well balanced, and that's a concern because classification models are best trained with balanced datasets. Use the following code to build a dataset containing 100 images of each person.

# %%
import numpy as np

mask = np.zeros(faces.target.shape, dtype=bool)

for target in np.unique(faces.target):
    mask[np.where(faces.target == target)[0][:100]] = 1
    
x_faces = faces.data[mask]
y_faces = faces.target[mask]
x_faces.shape
# Out:
# (500, 2914)

# %% [markdown]
# The next step is to normalize pixel values by dividing them by 255. After that, we'll split the data for training and testing. Rather than allow Keras to do the splitting, we'll use Scikit-learn so we can test the network with data it hasn't seen before.

# %%
from sklearn.model_selection import train_test_split

face_images = x_faces / 255
x_train, x_test, y_train, y_test = train_test_split(face_images, y_faces, train_size=0.8, stratify=y_faces, random_state=0)

# %% [markdown]
# ## Build and train a neural network
#
# Start by using Keras to build and train a neural network containing one hidden layer with 512 neurons. We'll use `sparse_categorical_crossentropy` as the loss function and a `softmax` output layer since this is a multiclass classification task. We will also use `adam` as the optimization algorithm. Rather than use a fixed learning rate, `adam` varies the learning rate as training proceeds so the network learns faster in the early stages of training and (hopefully) converges more accurately toward a solution in later stages.

# %%
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
 
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(image_width * image_height,)))
model.add(Dense(class_count, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               1492480
#
#  dense_1 (Dense)             (None, 5)                 2565
#
# =================================================================
# Total params: 1,495,045
# Trainable params: 1,495,045
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now train the network.

# %%
hist = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=100, batch_size=20)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 10ms/step - loss: 3.2424 - accuracy: 0.1975 - val_loss: 1.9515 - val_accuracy: 0.2400
# Epoch 2/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.6811 - accuracy: 0.2700 - val_loss: 1.5522 - val_accuracy: 0.3300
# Epoch 3/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.4595 - accuracy: 0.3750 - val_loss: 1.4775 - val_accuracy: 0.3300
# Epoch 4/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3514 - accuracy: 0.4950 - val_loss: 1.3999 - val_accuracy: 0.4600
# Epoch 5/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3504 - accuracy: 0.4600 - val_loss: 1.5034 - val_accuracy: 0.4200
# Epoch 6/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.3908 - accuracy: 0.4475 - val_loss: 1.2786 - val_accuracy: 0.4700
# Epoch 7/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1706 - accuracy: 0.5825 - val_loss: 1.3038 - val_accuracy: 0.4600
# Epoch 8/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1792 - accuracy: 0.5475 - val_loss: 1.2839 - val_accuracy: 0.5000
# Epoch 9/100
# 20/20 [==============================] - 0s 4ms/step - loss: 1.1324 - accuracy: 0.5900 - val_loss: 1.2144 - val_accuracy: 0.4900
# Epoch 10/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9566 - accuracy: 0.7225 - val_loss: 1.0336 - val_accuracy: 0.6600
# Epoch 11/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.9178 - accuracy: 0.6975 - val_loss: 1.1534 - val_accuracy: 0.5300
# Epoch 12/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8985 - accuracy: 0.6750 - val_loss: 1.0694 - val_accuracy: 0.5700
# Epoch 13/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.8352 - accuracy: 0.7525 - val_loss: 0.9491 - val_accuracy: 0.6800
# Epoch 14/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7753 - accuracy: 0.7375 - val_loss: 1.0503 - val_accuracy: 0.5400
# Epoch 15/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.7603 - accuracy: 0.7450 - val_loss: 0.9468 - val_accuracy: 0.6300
# Epoch 16/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6985 - accuracy: 0.7850 - val_loss: 0.9442 - val_accuracy: 0.6000
# Epoch 17/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6510 - accuracy: 0.8150 - val_loss: 0.8426 - val_accuracy: 0.6700
# Epoch 18/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5855 - accuracy: 0.8500 - val_loss: 0.8731 - val_accuracy: 0.6700
# Epoch 19/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.6561 - accuracy: 0.7900 - val_loss: 0.9292 - val_accuracy: 0.6600
# Epoch 20/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5759 - accuracy: 0.8050 - val_loss: 0.8377 - val_accuracy: 0.6700
# Epoch 21/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5658 - accuracy: 0.8375 - val_loss: 0.8649 - val_accuracy: 0.7100
# Epoch 22/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5821 - accuracy: 0.8100 - val_loss: 0.8120 - val_accuracy: 0.6600
# Epoch 23/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5426 - accuracy: 0.8325 - val_loss: 1.1015 - val_accuracy: 0.6200
# Epoch 24/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5688 - accuracy: 0.8150 - val_loss: 0.9865 - val_accuracy: 0.6000
# Epoch 25/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5145 - accuracy: 0.8350 - val_loss: 0.9467 - val_accuracy: 0.6400
# Epoch 26/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4299 - accuracy: 0.8750 - val_loss: 0.7287 - val_accuracy: 0.7000
# Epoch 27/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3984 - accuracy: 0.8875 - val_loss: 0.8174 - val_accuracy: 0.7200
# Epoch 28/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3879 - accuracy: 0.9075 - val_loss: 0.8664 - val_accuracy: 0.7200
# Epoch 29/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3832 - accuracy: 0.9000 - val_loss: 0.7655 - val_accuracy: 0.7300
# Epoch 30/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3654 - accuracy: 0.9050 - val_loss: 0.7151 - val_accuracy: 0.7400
# Epoch 31/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.4543 - accuracy: 0.8300 - val_loss: 0.9545 - val_accuracy: 0.6600
# Epoch 32/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3580 - accuracy: 0.9100 - val_loss: 0.6984 - val_accuracy: 0.7200
# Epoch 33/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3638 - accuracy: 0.8875 - val_loss: 1.2869 - val_accuracy: 0.5600
# Epoch 34/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.5154 - accuracy: 0.8150 - val_loss: 1.0267 - val_accuracy: 0.6900
# Epoch 35/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3389 - accuracy: 0.8925 - val_loss: 0.6517 - val_accuracy: 0.7300
# Epoch 36/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3054 - accuracy: 0.9100 - val_loss: 0.8016 - val_accuracy: 0.7000
# Epoch 37/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.3000 - accuracy: 0.9275 - val_loss: 0.6105 - val_accuracy: 0.7900
# Epoch 38/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2984 - accuracy: 0.9250 - val_loss: 0.7196 - val_accuracy: 0.6700
# Epoch 39/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2896 - accuracy: 0.9150 - val_loss: 0.5697 - val_accuracy: 0.7900
# Epoch 40/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2299 - accuracy: 0.9375 - val_loss: 0.7549 - val_accuracy: 0.7000
# Epoch 41/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2317 - accuracy: 0.9350 - val_loss: 0.6495 - val_accuracy: 0.7500
# Epoch 42/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2104 - accuracy: 0.9625 - val_loss: 0.5615 - val_accuracy: 0.7700
# Epoch 43/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2321 - accuracy: 0.9325 - val_loss: 0.8294 - val_accuracy: 0.6900
# Epoch 44/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2710 - accuracy: 0.9225 - val_loss: 0.5908 - val_accuracy: 0.7800
# Epoch 45/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2168 - accuracy: 0.9450 - val_loss: 0.6926 - val_accuracy: 0.7000
# Epoch 46/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2297 - accuracy: 0.9350 - val_loss: 0.7405 - val_accuracy: 0.7400
# Epoch 47/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2127 - accuracy: 0.9350 - val_loss: 0.5847 - val_accuracy: 0.7600
# Epoch 48/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2240 - accuracy: 0.9300 - val_loss: 0.6470 - val_accuracy: 0.7700
# Epoch 49/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2214 - accuracy: 0.9350 - val_loss: 0.6663 - val_accuracy: 0.7300
# Epoch 50/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1884 - accuracy: 0.9475 - val_loss: 0.6140 - val_accuracy: 0.7600
# Epoch 51/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1524 - accuracy: 0.9650 - val_loss: 0.6273 - val_accuracy: 0.7600
# Epoch 52/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1734 - accuracy: 0.9625 - val_loss: 0.7662 - val_accuracy: 0.7600
# Epoch 53/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2221 - accuracy: 0.9350 - val_loss: 0.7940 - val_accuracy: 0.7000
# Epoch 54/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1292 - accuracy: 0.9750 - val_loss: 0.5415 - val_accuracy: 0.7700
# Epoch 55/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1169 - accuracy: 0.9875 - val_loss: 0.6673 - val_accuracy: 0.8000
# Epoch 56/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1138 - accuracy: 0.9800 - val_loss: 0.5512 - val_accuracy: 0.8100
# Epoch 57/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1105 - accuracy: 0.9900 - val_loss: 0.7287 - val_accuracy: 0.7500
# Epoch 58/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1257 - accuracy: 0.9825 - val_loss: 0.7421 - val_accuracy: 0.7700
# Epoch 59/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1141 - accuracy: 0.9800 - val_loss: 0.6290 - val_accuracy: 0.8200
# Epoch 60/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9875 - val_loss: 0.6253 - val_accuracy: 0.7900
# Epoch 61/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0914 - accuracy: 0.9925 - val_loss: 0.6031 - val_accuracy: 0.7500
# Epoch 62/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1397 - accuracy: 0.9675 - val_loss: 0.5765 - val_accuracy: 0.8000
# Epoch 63/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1186 - accuracy: 0.9725 - val_loss: 0.7525 - val_accuracy: 0.7500
# Epoch 64/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0988 - accuracy: 0.9825 - val_loss: 0.6808 - val_accuracy: 0.7900
# Epoch 65/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1096 - accuracy: 0.9750 - val_loss: 0.6570 - val_accuracy: 0.7800
# Epoch 66/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.2567 - accuracy: 0.9050 - val_loss: 0.6322 - val_accuracy: 0.7800
# Epoch 67/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1604 - accuracy: 0.9575 - val_loss: 0.7937 - val_accuracy: 0.7200
# Epoch 68/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0948 - accuracy: 0.9875 - val_loss: 0.5638 - val_accuracy: 0.8000
# Epoch 69/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0944 - accuracy: 0.9875 - val_loss: 0.5496 - val_accuracy: 0.8100
# Epoch 70/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0683 - accuracy: 0.9950 - val_loss: 0.6859 - val_accuracy: 0.7700
# Epoch 71/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0790 - accuracy: 0.9950 - val_loss: 0.6022 - val_accuracy: 0.8100
# Epoch 72/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1001 - accuracy: 0.9825 - val_loss: 1.0313 - val_accuracy: 0.6800
# Epoch 73/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1115 - accuracy: 0.9725 - val_loss: 0.8498 - val_accuracy: 0.7700
# Epoch 74/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0823 - accuracy: 0.9825 - val_loss: 0.7161 - val_accuracy: 0.8100
# Epoch 75/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0824 - accuracy: 0.9850 - val_loss: 0.6064 - val_accuracy: 0.8100
# Epoch 76/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1341 - accuracy: 0.9575 - val_loss: 1.1556 - val_accuracy: 0.6900
# Epoch 77/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.1070 - accuracy: 0.9750 - val_loss: 0.6276 - val_accuracy: 0.7800
# Epoch 78/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0581 - accuracy: 0.9950 - val_loss: 0.6631 - val_accuracy: 0.8000
# Epoch 79/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0787 - accuracy: 0.9875 - val_loss: 0.9220 - val_accuracy: 0.7300
# Epoch 80/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0812 - accuracy: 0.9875 - val_loss: 0.6043 - val_accuracy: 0.8400
# Epoch 81/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0857 - accuracy: 0.9825 - val_loss: 0.7139 - val_accuracy: 0.7300
# Epoch 82/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0624 - accuracy: 0.9925 - val_loss: 0.6775 - val_accuracy: 0.7700
# Epoch 83/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 0.6164 - val_accuracy: 0.8200
# Epoch 84/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0447 - accuracy: 1.0000 - val_loss: 0.6313 - val_accuracy: 0.7400
# Epoch 85/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0478 - accuracy: 0.9975 - val_loss: 0.6585 - val_accuracy: 0.8200
# Epoch 86/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0448 - accuracy: 1.0000 - val_loss: 0.6090 - val_accuracy: 0.8000
# Epoch 87/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0364 - accuracy: 0.9975 - val_loss: 0.5670 - val_accuracy: 0.7800
# Epoch 88/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0377 - accuracy: 1.0000 - val_loss: 0.6509 - val_accuracy: 0.8100
# Epoch 89/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0517 - accuracy: 0.9975 - val_loss: 0.6262 - val_accuracy: 0.8200
# Epoch 90/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0942 - accuracy: 0.9800 - val_loss: 0.5572 - val_accuracy: 0.8200
# Epoch 91/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 0.9775 - val_loss: 0.5966 - val_accuracy: 0.8100
# Epoch 92/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0418 - accuracy: 0.9925 - val_loss: 0.6085 - val_accuracy: 0.7600
# Epoch 93/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0468 - accuracy: 0.9950 - val_loss: 0.5297 - val_accuracy: 0.8500
# Epoch 94/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 1.0000 - val_loss: 0.5658 - val_accuracy: 0.8000
# Epoch 95/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.6526 - val_accuracy: 0.8200
# Epoch 96/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.6153 - val_accuracy: 0.8200
# Epoch 97/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0262 - accuracy: 1.0000 - val_loss: 0.6284 - val_accuracy: 0.8200
# Epoch 98/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.6077 - val_accuracy: 0.8000
# Epoch 99/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0238 - accuracy: 1.0000 - val_loss: 0.6950 - val_accuracy: 0.7700
# Epoch 100/100
# 20/20 [==============================] - 0s 4ms/step - loss: 0.0336 - accuracy: 1.0000 - val_loss: 0.5964 - val_accuracy: 0.7900

# %% [markdown]
# Plot the training and validation accuracy.

# %%
acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []

# %% [markdown]
# Finally, use the test data to generate a confusion matrix to visualize how the network performs.

# %%
from sklearn.metrics import ConfusionMatrixDisplay as cmd

sns.reset_orig()
y_pred = model.predict(x_test)
fig, ax = plt.subplots(figsize=(5, 5))
ax.grid(False)

cmd.from_predictions(y_test, y_pred.argmax(axis=1),
                     display_labels=faces.target_names, colorbar=False,
                     cmap='Blues', xticks_rotation='vertical', ax=ax)

# %% [markdown]
# How many times did the model correctly identify George W. Bush? How many times did it identify him as someone else?
