# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten
from tensorflow.keras.models import Sequential
 
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
x_train = train_images.reshape(60000, 28, 28, 1) / 255
x_test = test_images.reshape(10000, 28, 28, 1) / 255
y_train = to_categorical(train_labels)
y_test = to_categorical(test_labels)
 
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
 
hist = model.fit(x_train, y_train,
                 validation_data=(x_test, y_test),
                 epochs=10, batch_size=50)
# Out:
# Epoch 1/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.1398 - accuracy: 0.9577 - val_loss: 0.0468 - val_accuracy: 0.9855
# Epoch 2/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0438 - accuracy: 0.9863 - val_loss: 0.0354 - val_accuracy: 0.9890
# Epoch 3/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0287 - accuracy: 0.9909 - val_loss: 0.0333 - val_accuracy: 0.9888
# Epoch 4/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0211 - accuracy: 0.9934 - val_loss: 0.0319 - val_accuracy: 0.9901
# Epoch 5/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0164 - accuracy: 0.9949 - val_loss: 0.0362 - val_accuracy: 0.9885
# Epoch 6/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0284 - val_accuracy: 0.9909
# Epoch 7/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0108 - accuracy: 0.9966 - val_loss: 0.0318 - val_accuracy: 0.9914
# Epoch 8/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0085 - accuracy: 0.9971 - val_loss: 0.0339 - val_accuracy: 0.9907
# Epoch 9/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0349 - val_accuracy: 0.9908
# Epoch 10/10
# 1200/1200 [==============================] - 11s 9ms/step - loss: 0.0061 - accuracy: 0.9979 - val_loss: 0.0404 - val_accuracy: 0.9897

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = hist.history['accuracy']
val_acc = hist.history['val_accuracy']
epochs = range(1, len(acc) + 1)
 
plt.plot(epochs, acc, '-', label='Training Accuracy')
plt.plot(epochs, val_acc, ':', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.plot()
# Out:
# []
