# %%
import onnx
from onnx2keras import onnx_to_keras

onnx_model = onnx.load('Data/yolov3-10.onnx')
print([node.name for node in onnx_model.graph.input])
# Out:
# ['input_1', 'image_shape']

# %%
model = onnx_to_keras(onnx_model, input_names=['input_1', 'image_shape'])
# Out:
# INFO:onnx2keras:Converter is called.
# DEBUG:onnx2keras:List input shapes:
# DEBUG:onnx2keras:None
# DEBUG:onnx2keras:List inputs:
# DEBUG:onnx2keras:Input 0 -> input_1.
# DEBUG:onnx2keras:Input 1 -> image_shape.
# DEBUG:onnx2keras:List outputs:
# DEBUG:onnx2keras:Output 0 -> yolonms_layer_1/ExpandDims_1:0.
# DEBUG:onnx2keras:Output 1 -> yolonms_layer_1/ExpandDims_3:0.
# DEBUG:onnx2keras:Output 2 -> yolonms_layer_1/concat_2:0.
# DEBUG:onnx2keras:Gathering weights to dictionary.
# DEBUG:onnx2keras:Found weight var69 with shape (32,).
# DEBUG:onnx2keras:Found weight var64 with shape (64,).
# DEBUG:onnx2keras:Found weight var6 with shape (256,).
# DEBUG:onnx2keras:Found weight var5 with shape (128,).
# DEBUG:onnx2keras:Found weight var22 with shape (1024,).
# DEBUG:onnx2keras:Found weight var21 with shape (512,).
# DEBUG:onnx2keras:Found weight scale9 with shape (256,).
# DEBUG:onnx2keras:Found weight scale8 with shape (128,).
# DEBUG:onnx2keras:Found weight scale71 with shape (32,).
# ...
